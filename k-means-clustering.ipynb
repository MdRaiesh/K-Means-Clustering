# %% [markdown]
# <a href="https://www.kaggle.com/code/mdraiesh9648/k-means-clustering?scriptVersionId=108767533" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # K-Means Clustering

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('../input/student-dataset/student_clustering.csv')
print("The shape of data is",df.shape)
df.head()
# Out:
# The shape of data is (200, 2)
#    cgpa   iq
# 0  5.13   88
# 1  5.90  113
# 2  8.36   93
# 3  8.27   97
# 4  5.45  110

# %%
import matplotlib.pyplot as plt
plt.scatter(df['cgpa'],df['iq'])

# %%
from sklearn.cluster import KMeans

# %%
wcss=[]

for i in range(1,11):
    km=KMeans(n_clusters=i)
    km.fit_predict(df)
    wcss.append(km.inertia_)

# %%
wcss
# Out:
# [29957.898288,
#  4184.14127,
#  2362.7133489999997,
#  681.96966,
#  514.1616803171114,
#  388.8524026875981,
#  302.5473746759043,
#  242.41587382556412,
#  206.72239593998563,
#  177.88703484948792]

# %%
plt.plot(range(1,11),wcss)

# %%
X=df.iloc[:,:].values
km=KMeans(n_clusters=4)
y_means=km.fit_predict(X)

# %%
y_means
# Out:
# array([2, 3, 1, 1, 3, 3, 1, 0, 3, 1, 2, 3, 1, 2, 3, 1, 3, 1, 3, 3, 1, 2,
#        1, 2, 2, 1, 2, 0, 1, 3, 0, 3, 0, 3, 1, 1, 0, 3, 2, 3, 2, 1, 1, 2,
#        0, 0, 1, 3, 0, 3, 2, 2, 0, 1, 0, 3, 3, 0, 3, 0, 3, 1, 1, 0, 2, 0,
#        1, 2, 3, 1, 3, 0, 1, 2, 3, 0, 3, 0, 2, 1, 1, 0, 3, 2, 0, 2, 0, 3,
#        0, 3, 0, 0, 1, 2, 1, 1, 0, 1, 2, 0, 3, 2, 2, 0, 2, 2, 1, 2, 0, 0,
#        1, 0, 3, 3, 1, 0, 1, 3, 0, 2, 2, 3, 1, 0, 1, 2, 1, 3, 2, 1, 1, 3,
#        2, 2, 3, 0, 3, 2, 1, 1, 1, 2, 3, 2, 2, 0, 2, 0, 3, 2, 0, 2, 0, 0,
#        2, 1, 3, 0, 3, 1, 2, 0, 3, 1, 0, 2, 3, 2, 2, 0, 0, 3, 0, 2, 2, 1,
#        0, 3, 2, 0, 0, 3, 3, 3, 1, 2, 1, 1, 0, 3, 1, 1, 2, 2, 1, 2, 0, 3,
#        3, 0], dtype=int32)

# %%
X[y_means==3,1]
# Out:
# array([113., 110., 109., 110., 110., 108., 111., 111., 113., 106., 112.,
#        106., 108., 113., 108., 109., 108., 111., 109., 104., 111., 109.,
#        109., 112., 111., 109., 108., 110., 109., 111., 108., 109., 109.,
#        111., 112., 109., 111., 107., 111., 110., 108., 109., 110., 108.,
#        108., 110., 107., 111., 112., 108.])

# %%
plt.scatter(X[y_means==0,0],X[y_means==0,1],color='blue')
plt.scatter(X[y_means==1,0],X[y_means==1,1],color='red')
plt.scatter(X[y_means==2,0],X[y_means==2,1],color='green')
plt.scatter(X[y_means==3,0],X[y_means==3,1],color='yellow')

# %% [markdown]
# # K-Means on 3D Data

# %%
from sklearn.datasets import make_blobs
centroids=[(-5,-5,5),(5,5,-5),(3.5,-2.5,4),(-2.5,2.5,-4)]
cluster_std=[1,1,1,1]
X,y=make_blobs(n_samples=200,cluster_std=cluster_std,centers=centroids,n_features=3,random_state=1)

# %%
X
# Out:
# array([[ 4.33424548,  3.32580419, -4.17497018],
#        [-3.32246719,  3.22171129, -4.625342  ],
#        [-6.07296862, -4.13459237,  2.6984613 ],
#        [ 6.90465871,  6.1110567 , -4.3409502 ],
#        [-2.60839207,  2.95015551, -2.2346649 ],
#        [ 5.88490881,  4.12271848, -5.86778722],
#        [-4.68484061, -4.15383935,  4.14048406],
#        [-1.82542929,  3.96089238, -3.4075272 ],
#        [-5.34385368, -4.95640314,  4.37999916],
#        [ 4.91549197,  4.70263812, -4.582698  ],
#        [-3.80108212, -4.81484358,  4.62471505],
#        [ 4.6735005 ,  3.65732421, -3.88561702],
#        [-6.23005814, -4.4494625 ,  5.79280687],
#        [-3.90232915,  2.95112294, -4.6949209 ],
#        [ 3.72744124,  5.31354772, -4.49681519],
#        [-3.3088472 ,  3.05743945, -3.81896126],
#        [ 2.70273021, -2.21732429,  3.17390257],
#        [ 4.06438286, -0.36217193,  3.214466  ],
#        [ 4.69268607, -2.73794194,  5.15528789],
#        [ 4.1210827 , -1.5438783 ,  3.29415949],
# ...

# %%
import plotly.express as px
fig=px.scatter_3d(x=X[:,0],y=X[:,1],z=X[:,2])
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.14.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
wcss=[]

for i in range(1,21):
    km=KMeans(n_clusters=i)
    km.fit_predict(df)
    wcss.append(km.inertia_)

# %%
plt.plot(range(1,21),wcss)

# %%
km=KMeans(n_clusters=4)
y_pred=km.fit_predict(X)

# %%
df=pd.DataFrame()

df['col1']=X[:,0]
df['col2']=X[:,1]
df['col3']=X[:,2]
df['label']=y_pred

# %%
fig=px.scatter_3d(df,x='col1',y='col2',z='col3',color='label')
fig.show()
# Out:
# <div>                            <div id="5e0d89ed-3961-4458-a57b-d5ebb779880c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5e0d89ed-3961-4458-a57b-d5ebb779880c")) {                    Plotly.newPlot(                        "5e0d89ed-3961-4458-a57b-d5ebb779880c",                        [{"hovertemplate":"col1=%{x}<br>col2=%{y}<br>col3=%{z}<br>label=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[1,0,2,1,0,1,2,0,2,1,2,1,2,0,1,0,3,3,3,3,2,3,0,2,2,1,0,3,1,0,3,1,1,2,0,1,2,0,3,3,2,0,2,1,0,3,3,1,0,2,1,3,3,0,2,2,0,3,3,1,2,0,0,0,3,2,3,1,2,0,3,1,1,1,2,1,1,1,2,3,0,2,0,0,2,0,1,2,2,0,1,0,0,3,0,2,2,1,2,2,1,2,2,1,0,0,0,3,3,0,3,1,3,0,3,0,2,0,3,1,2,1,3,3,0,2,3,1,3,2,3,2,0,2,1,3,3,1,0,0,2,1,1,0,2,1,1,2,0,1,0,1,3,3,1,3,2,0,3,1,1,2,2,3,3,2,2,3,
# ...
